# %% [markdown]
# Lee el archivo en txt y lo separa en lineas

# %%
from pylabeador import syllabify

file_name = "prueba.txt" 
file_name_mod = file_name.replace(".txt", "") # Elim
file_name_mod = file_name_mod + "m.txt" # Nombre del

mod_file = open("../Final/" + file_name_mod, 'w', encoding='utf-8') # Creo el acrchi
raw_file = open("../Final/" + file_name, 'r', encoding='utf-8') # Abro el archivo pa

for x in raw_file: 
    xf = x.replace(".", "")
    xr = xf.replace(",", "")
    xs = xr.replace("(", "")
    xt = xs.replace(")", "")
    xu = xt.replace(":", "")
    xv = xu.replace(";", "")
    xw = xv.replace("¿", "")
    xx = xw.replace("?", "")
    xy = xx.replace("-", "")
    xz = xy.replace("!", "")
    xa = xz.replace("¡", "")
    xb = xa.replace("\"", "")
    xc = xb.replace("—", "")

    mod_file.write(xc)

mod_file.close()
raw_file.close()

# Contar lineas sin espacios y guardarlas--------
archivo = open("../Final/pruebam.txt", encoding='utf-8')

Content = archivo.read()
CoList = Content.split("\n")

for i in range (CoList.count('')):
    CoList.remove('')

print(CoList)
# Out:
# ['asarán estos días como pasan', 'todos los días malos de la vida', 'Amainarán los vientos que te arrasan', 'Se estancará la sangre de tu herida', 'El alma errante volverá a su nido', 'Lo que ayer se perdió será encontrado', 'El sol será sin mancha concebido', 'y saldrá nuevamente en tu costado', 'Y dirás frente al mar Cómo he podido', 'anegado sin brújula y perdido', 'llegar a puerto con las velas rotas', 'Y una voz te dirá Que no lo sabes', 'El mismo viento que rompió tus naves', 'es el que hace volar a las gaviotas']

# %% [markdown]
# obtiene las silabas de las palabras del texto

# %%
resultado = []
palabras = []
finales = []
suma = 0
for line in CoList:
    text = line.split()
   
    #print(text)
    finales.append(text[-1])    # guarda las ultimas palabras_finales de cada linea

    for word in text:   # separa las palabras_finales de cada oracion
        palabras.append(word)
        
    
for palabra in palabras:    # obtiene las silabas de las palabras de las oraciones
    resultado.append(syllabify(palabra))


#print(resultado)
print(finales)

# cuenta las silabas del poema 
for i in resultado:
    suma += len(i)
    #print(i)

print(suma)
# Out:
# ['pasan', 'vida', 'arrasan', 'herida', 'nido', 'encontrado', 'concebido', 'costado', 'podido', 'perdido', 'rotas', 'sabes', 'naves', 'gaviotas']
# 167

# %%
def tipo_acentuacion(palabras_finales, silabas):
     vocales = ['a', 'e', 'i', 'o', 'u']
     vocal_acento = ['á', 'é', 'í', 'ó', 'ú']
     consonantes = ['b', 'c', 'd', 'f', 'g', 'h', 'j', 'k', 'l', 'm', 'n', 'ñ', 'p', 'q', 'r', 's', 't', 'v', 'w', 'x', 'y', 'z']
     monosilabas = []
     agudas = []
     graves = []
     esdrujulas = []
     clasificador = []

     nuevas_finales = []
     nuevas_silabas = []
     flagA = False
     flagG = False

     # para las monosilabas
     # tienen 1, 2 o 3 letras
     for palabra in palabras_finales[:]:  
          if len(palabra) <= 3:
               clasificador.append("monosilaba")
               monosilabas.append(palabra)

               # palabras_finales.remove(palabra)
               # for silaba in silabas:
               #      if palabra == silaba:
               #           silabas.remove(palabra)
               continue
          
          nuevas_finales.append(palabra)

     nuevas_silabas = [silaba for silaba in silabas if silaba not in monosilabas]

     palabras_finales = nuevas_finales
     silabas = nuevas_silabas
               # return 1
               
     for silaba in silabas:
          print(silaba)
          # agudas - acento en la ultima silaba
          if silaba[-1] in vocal_acento:
               clasificador.append("aguda")
               agudas.append(palabra)
               palabras_finales.remove(palabra)
               flagA = True
               continue
          
          # graves - acento en la penultima
          elif silaba[-2] in vocal_acento:
               clasificador.append("grave")
               graves.append(palabra)
               palabras_finales.remove(palabra)
               flagG = True
               continue

          # esdrujulas - siempre con acento
          elif any(palabra in vocal_acento for palabra in palabras):
               clasificador.append("esdrujula")
               esdrujulas.append(palabra)
               palabras_finales.remove(palabra)
               continue

     if flagA == False or flagG == False:
          for palabra in palabras_finales[:]:
               # para las agudas
               # Si la palabra termina en vocal, "n" o "s" y no lleva tilde 
               if palabra[-1] in vocales or palabra[-1] in ['n','s'] or palabra not in vocal_acento:
                    clasificador.append("aguda")
                    agudas.append(palabra)
                    palabras_finales.remove(palabra)
                    continue
                    # return 1
               
               # para las llanas o graves
               # llevan tilde en la penultima silaba
               if palabra[-1] not in ['n','s'] or palabra not in vocal_acento:
                    clasificador.append("grave")
                    graves.append(palabra)
                    palabras_finales.remove(palabra)
                    continue
                    # return 0
               
               # para las esdrújulas
               # siempre llevan tilde
               # if any(palabra in vocal_acento for palabra in palabras):
               #      clasificador.append("esdrujula")
               #      esdrujulas.append(palabra)
               #      palabras_finales.remove(palabra)
               #      continue
               #      # return -1
          
     print("Monosilabas =", monosilabas)
     print("Agudas =", agudas)
     print("Graves =", graves)
     print("Esdrujulas =", esdrujulas)
     print("palabras_finales = ", palabras_finales)

     print("clasificador =", clasificador) 
     return clasificador

# %%
silabas_finales = []

for palabra in finales:
     silabas_finales.append(syllabify(palabra))

print("f-",finales)
print("sf-",silabas_finales)
tipos = tipo_acentuacion(finales, silabas_finales)

for tipo in tipos:
     if tipo == 'aguda' or tipo == 'monosilada':
          suma += 1
     elif tipo == 'grave':
          suma += 0
     elif tipo == 'esdrujula':
          suma -= 1

print(suma)
# Out:
# f- ['pasan', 'vida', 'arrasan', 'herida', 'nido', 'encontrado', 'concebido', 'costado', 'podido', 'perdido', 'rotas', 'sabes', 'naves', 'gaviotas']
# sf- [['pa', 'san'], ['vi', 'da'], ['a', 'rra', 'san'], ['he', 'ri', 'da'], ['ni', 'do'], ['en', 'con', 'tra', 'do'], ['con', 'ce', 'bi', 'do'], ['cos', 'ta', 'do'], ['po', 'di', 'do'], ['per', 'di', 'do'], ['ro', 'tas'], ['sa', 'bes'], ['na', 'ves'], ['ga', 'vio', 'tas']]
# ['pa', 'san']
# ['vi', 'da']
# ['a', 'rra', 'san']
# ['he', 'ri', 'da']
# ['ni', 'do']
# ['en', 'con', 'tra', 'do']
# ['con', 'ce', 'bi', 'do']
# ['cos', 'ta', 'do']
# ['po', 'di', 'do']
# ['per', 'di', 'do']
# ['ro', 'tas']
# ['sa', 'bes']
# ['na', 'ves']
# ['ga', 'vio', 'tas']
# Monosilabas = []
# Agudas = ['pasan', 'vida', 'arrasan', 'herida', 'nido', 'encontrado', 'concebido', 'costado', 'podido', 'perdido', 'rotas', 'sabes', 'naves', 'gaviotas']
# Graves = []
# Esdrujulas = []
# palabras_finales =  []
# clasificador = ['aguda', 'aguda', 'aguda', 'aguda', 'aguda', 'aguda', 'aguda', 'aguda', 'aguda', 'aguda', 'aguda', 'aguda', 'aguda', 'aguda']
# 181

# %%
# Muestra las lineas con rimas consonantes$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
consonantes = []

print("++++++++++++++++++++++++++++++++ Rimas consonantes: +++++++++++++++++++++++++++++++++\n")

for j in range (len(CoList)-1):
    
    for k in range (len(CoList)-j-1):
        #print(j, j+k+1)
        
        if (CoList[j][-1] == CoList[j+k+1][-1]) and (CoList[j][-2] == CoList[j+k+1][-2]) and (CoList[j][-3] == CoList[j+k+1][-3]):
            #print(CoList[j])
            #print(CoList[j+k+1])
            if consonantes.count(CoList[j]) == 0:
                consonantes.append(CoList[j])
                
            if consonantes.count(CoList[j+k+1]) == 0:
                consonantes.append(CoList[j+k+1])
    consonantes.append(" ")

for l in range (len(consonantes)):
    print(consonantes[l])
#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$



# Eliminacion de letras consonantes para obtener rimas asonantes %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
cpy = CoList
cpy2 = []
l_cons = ('b', 'c', 'd', 'f', 'g', 'h', 'j', 'k', 'l', 'm', 'n', 'ñ', 'p', 'q', 'r', 's', 't', 'v', 'w', 'x', 'y', 'z')

for p in range(len(cpy)):
    texto = cpy[p]
    for letra in l_cons:
        texto = texto.replace(letra, "")
    
    cpy2.append(texto)

    #Invierte la cadena
    texto = texto[::-1]

#print(cpy2)
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



# Muestra las lineas con rimas asonantes^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
asonantes = []

print("++++++++++++++++++++++++++++++++ Rimas asonantes: +++++++++++++++++++++++++++++++++\n")

for j in range (len(cpy2)-1):
    
    for k in range (len(cpy2)-j-1):
        #print(j, j+k+1)
        
        if (cpy2[j][-1] == cpy2[j+k+1][-1]) and (cpy2[j][-2] == cpy2[j+k+1][-2]):
            # print(CoList[j])
            # print(CoList[j+k+1])
            if (asonantes.count(CoList[j]) == 0): #and (consonantes.count(CoList[j]) == 0):
                asonantes.append(CoList[j])
                
            if (asonantes.count(CoList[j+k+1]) == 0): #and (consonantes.count(CoList[j+k+1]) == 0):
                asonantes.append(CoList[j+k+1])
    asonantes.append(" ")

for l in range (len(asonantes)):
    print(asonantes[l])
#^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

archivo.close()
# Out:
# ++++++++++++++++++++++++++++++++ Rimas consonantes: +++++++++++++++++++++++++++++++++
#
# asarán estos días como pasan
# Amainarán los vientos que te arrasan
#
# todos los días malos de la vida
# Se estancará la sangre de tu herida
#
#
#
# El alma errante volverá a su nido
# El sol será sin mancha concebido
# Y dirás frente al mar Cómo he podido
# anegado sin brújula y perdido
#
# Lo que ayer se perdió será encontrado
# y saldrá nuevamente en tu costado
#
#
#
#
#
# llegar a puerto con las velas rotas
# es el que hace volar a las gaviotas
#
#
#
# ++++++++++++++++++++++++++++++++ Rimas asonantes: +++++++++++++++++++++++++++++++++
#
# asarán estos días como pasan
# Amainarán los vientos que te arrasan
#
# todos los días malos de la vida
# Se estancará la sangre de tu herida
#
#
#
# El alma errante volverá a su nido
# El sol será sin mancha concebido
# Y dirás frente al mar Cómo he podido
# anegado sin brújula y perdido
#
# Lo que ayer se perdió será encontrado
# y saldrá nuevamente en tu costado
#
#
#
#
#
# llegar a puerto con las velas rotas
# es el que hace volar a las gaviotas
#
# Y una voz te dirá Que no lo sabes
# El mismo viento que rompió tus naves
